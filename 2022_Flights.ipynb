# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The U.S. Department of Transportation's (DOT) Bureau of Transportation Statistics tracks the on-time performance of domestic flights operated by large air carriers.
# This dataset is collected from the Bureau of Transportation Statistics, Govt. of the USA. This data is open-sourced under U.S. Govt. Works.  I dowload 12 csv file that represents each month of 2022. This dataset contains all US domestic flights in 2022.
#
# Here is the URL of the dataset.
#
# https://www.transtats.bts.gov/DL_SelectFields.aspx?gnoyr_VQ=FGK&QO_fu146_anzr=b0-gvzr
#
# There are 120 features in each month csv. I prepared a list which shows the general information about flights.
# I choose 19 columns from every month of 2022, and then I concat them and save it as csv file. Dataset has 19 features in average with 7 million rows.

# %%
df1=pd.read_csv("Flights_2022_1.csv",sep=',', index_col=False, dtype='unicode')
df1.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       1     1          6         4  2022-01-06
# 1  2022       1     1          6         4  2022-01-06
# 2  2022       1     1          6         4  2022-01-06
# 3  2022       1     1          6         4  2022-01-06
# 4  2022       1     1          6         4  2022-01-06
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                                      DL
# 1                        DL                                      DL
# 2                        DL                                      DL
# 3                        DL                                      DL
# 4                        DL                                      DL
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19790                          DL  ...         NaN
# 1                    19790                          DL  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df1=df1[l]
df1
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            1     1          6         4  2022-01-06
# 1            1     1          6         4  2022-01-06
# 2            1     1          6         4  2022-01-06
# 3            1     1          6         4  2022-01-06
# 4            1     1          6         4  2022-01-06
# ...        ...   ...        ...       ...         ...
# 563732       1     1         24         1  2022-01-24
# 563733       1     1         24         1  2022-01-24
# 563734       1     1         24         1  2022-01-24
# 563735       1     1         24         1  2022-01-24
# 563736       1     1         24         1  2022-01-24
#
#        Marketing_Airline_Network       OriginCityName           DestCityName  \
# 0                             DL  Fort Lauderdale, FL           New York, NY
# 1                             DL          Atlanta, GA    Fort Lauderdale, FL
# 2                             DL  Fort Lauderdale, FL            Atlanta, GA
# ...

# %%
df1.shape
# Out:
# (563737, 19)

# %%
df2=pd.read_csv("Flights_2022_2.csv",sep=',', index_col=False, dtype='unicode')
df2.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       1     2         28         1  2022-02-28
# 1  2022       1     2         28         1  2022-02-28
# 2  2022       1     2         28         1  2022-02-28
# 3  2022       1     2         28         1  2022-02-28
# 4  2022       1     2         28         1  2022-02-28
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# 4                        UA                            UA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19977                          UA  ...         NaN
# 1                    19977                          UA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df2=df2[l]
df2
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            1     2         28         1  2022-02-28
# 1            1     2         28         1  2022-02-28
# 2            1     2         28         1  2022-02-28
# 3            1     2         28         1  2022-02-28
# 4            1     2         28         1  2022-02-28
# ...        ...   ...        ...       ...         ...
# 519947       1     2         25         5  2022-02-25
# 519948       1     2         23         3  2022-02-23
# 519949       1     2         22         2  2022-02-22
# 519950       1     2         16         3  2022-02-16
# 519951       1     2         15         2  2022-02-15
#
#        Marketing_Airline_Network  OriginCityName     DestCityName DepDelay  \
# 0                             UA      Denver, CO   Dodge City, KS    -1.00
# 1                             UA     Kearney, NE       Denver, CO   -10.00
# 2                             UA    Meridian, MS      Houston, TX   -11.00
# ...

# %%
df2.shape
# Out:
# (519952, 19)

# %%
df3=pd.read_csv("Flights_2022_3.csv",sep=',', index_col=False, dtype='unicode')
df3.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       1     3          8         2  2022-03-08
# 1  2022       1     3         12         6  2022-03-12
# 2  2022       1     3         15         2  2022-03-15
# 3  2022       1     3         19         6  2022-03-19
# 4  2022       1     3         22         2  2022-03-22
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                                      DL
# 1                        DL                                      DL
# 2                        DL                                      DL
# 3                        DL                                      DL
# 4                        DL                                      DL
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19790                          DL  ...         NaN
# 1                    19790                          DL  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df3=df3[l]
df3
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            1     3          8         2  2022-03-08
# 1            1     3         12         6  2022-03-12
# 2            1     3         15         2  2022-03-15
# 3            1     3         19         6  2022-03-19
# 4            1     3         22         2  2022-03-22
# ...        ...   ...        ...       ...         ...
# 590537       1     3         31         4  2022-03-31
# 590538       1     3         17         4  2022-03-17
# 590539       1     3          8         2  2022-03-08
# 590540       1     3         25         5  2022-03-25
# 590541       1     3          7         1  2022-03-07
#
#        Marketing_Airline_Network   OriginCityName         DestCityName  \
# 0                             DL    Knoxville, TN          Atlanta, GA
# 1                             DL  Minneapolis, MN  Fort Lauderdale, FL
# 2                             DL    Knoxville, TN          Atlanta, GA
# ...

# %%
df3.shape
# Out:
# (590542, 19)

# %%
df4=pd.read_csv("Flights_2022_4.csv",sep=',', index_col=False, dtype='unicode')
df4.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       2     4          4         1  2022-04-04
# 1  2022       2     4          4         1  2022-04-04
# 2  2022       2     4          4         1  2022-04-04
# 3  2022       2     4          4         1  2022-04-04
# 4  2022       2     4          4         1  2022-04-04
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# 4                        UA                            UA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19977                          UA  ...         NaN
# 1                    19977                          UA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df4=df4[l]
df4
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            2     4          4         1  2022-04-04
# 1            2     4          4         1  2022-04-04
# 2            2     4          4         1  2022-04-04
# 3            2     4          4         1  2022-04-04
# 4            2     4          4         1  2022-04-04
# ...        ...   ...        ...       ...         ...
# 580285       2     4          4         1  2022-04-04
# 580286       2     4          4         1  2022-04-04
# 580287       2     4          4         1  2022-04-04
# 580288       2     4          4         1  2022-04-04
# 580289       2     4          4         1  2022-04-04
#
#        Marketing_Airline_Network            OriginCityName  \
# 0                             UA        Grand Junction, CO
# 1                             UA  Harlingen/San Benito, TX
# 2                             UA               Durango, CO
# 3                             UA               Houston, TX
# ...

# %%
df4.shape
# Out:
# (580290, 19)

# %%
df5=pd.read_csv("Flights_2022_5.csv",sep=',', index_col=False, dtype='unicode')
df5.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       2     5          3         2  2022-05-03
# 1  2022       2     5          4         3  2022-05-04
# 2  2022       2     5          1         7  2022-05-01
# 3  2022       2     5          2         1  2022-05-02
# 4  2022       2     5          3         2  2022-05-03
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                            AA_CODESHARE
# 1                        AA                            AA_CODESHARE
# 2                        AA                            AA_CODESHARE
# 3                        AA                            AA_CODESHARE
# 4                        AA                            AA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19805                          AA  ...         NaN
# 1                    19805                          AA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df5=df5[l]
df5
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            2     5          3         2  2022-05-03
# 1            2     5          4         3  2022-05-04
# 2            2     5          1         7  2022-05-01
# 3            2     5          2         1  2022-05-02
# 4            2     5          3         2  2022-05-03
# ...        ...   ...        ...       ...         ...
# 602945       2     5         29         7  2022-05-29
# 602946       2     5         29         7  2022-05-29
# 602947       2     5         29         7  2022-05-29
# 602948       2     5         29         7  2022-05-29
# 602949       2     5         29         7  2022-05-29
#
#        Marketing_Airline_Network  OriginCityName     DestCityName DepDelay  \
# 0                             AA  Washington, DC       Albany, NY     8.00
# 1                             AA  Washington, DC       Albany, NY    -8.00
# 2                             AA   Charlotte, NC  Tallahassee, FL    -7.00
# ...

# %%
df5.shape
# Out:
# (602950, 19)

# %%
df6=pd.read_csv("Flights_2022_6.csv",sep=',', index_col=False, dtype='unicode')
df6.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       2     6         27         1  2022-06-27
# 1  2022       2     6         28         2  2022-06-28
# 2  2022       2     6         29         3  2022-06-29
# 3  2022       2     6         30         4  2022-06-30
# 4  2022       2     6          1         3  2022-06-01
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                            AA_CODESHARE
# 1                        AA                            AA_CODESHARE
# 2                        AA                            AA_CODESHARE
# 3                        AA                            AA_CODESHARE
# 4                        AA                            AA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19805                          AA  ...         NaN
# 1                    19805                          AA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df6=df6[l]
df6
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            2     6         27         1  2022-06-27
# 1            2     6         28         2  2022-06-28
# 2            2     6         29         3  2022-06-29
# 3            2     6         30         4  2022-06-30
# 4            2     6          1         3  2022-06-01
# ...        ...   ...        ...       ...         ...
# 602052       2     6         21         2  2022-06-21
# 602053       2     6         21         2  2022-06-21
# 602054       2     6         22         3  2022-06-22
# 602055       2     6         22         3  2022-06-22
# 602056       2     6         23         4  2022-06-23
#
#        Marketing_Airline_Network      OriginCityName        DestCityName  \
# 0                             AA      South Bend, IN       Charlotte, NC
# 1                             AA      South Bend, IN       Charlotte, NC
# 2                             AA      South Bend, IN       Charlotte, NC
# ...

# %%
df6.shape
# Out:
# (602057, 19)

# %%
df7=pd.read_csv("Flights_2022_7.csv",sep=',', index_col=False, dtype='unicode')
df7.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       3     7         19         2  2022-07-19
# 1  2022       3     7         20         3  2022-07-20
# 2  2022       3     7         21         4  2022-07-21
# 3  2022       3     7         24         7  2022-07-24
# 4  2022       3     7         25         1  2022-07-25
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                            AA_CODESHARE
# 1                        AA                            AA_CODESHARE
# 2                        AA                            AA_CODESHARE
# 3                        AA                            AA_CODESHARE
# 4                        AA                            AA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19805                          AA  ...         NaN
# 1                    19805                          AA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df7=df7[l]
df7
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            3     7         19         2  2022-07-19
# 1            3     7         20         3  2022-07-20
# 2            3     7         21         4  2022-07-21
# 3            3     7         24         7  2022-07-24
# 4            3     7         25         1  2022-07-25
# ...        ...   ...        ...       ...         ...
# 618785       3     7          1         5  2022-07-01
# 618786       3     7          1         5  2022-07-01
# 618787       3     7          1         5  2022-07-01
# 618788       3     7          1         5  2022-07-01
# 618789       3     7          1         5  2022-07-01
#
#        Marketing_Airline_Network  OriginCityName DestCityName DepDelay  \
# 0                             AA  Washington, DC    Tulsa, OK    -5.00
# 1                             AA  Washington, DC    Tulsa, OK    19.00
# 2                             AA  Washington, DC    Tulsa, OK    -4.00
# ...

# %%
df7.shape
# Out:
# (618790, 19)

# %%
df8=pd.read_csv("Flights_2022_8.csv",sep=',', index_col=False, dtype='unicode')
df8.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       3     8         17         3  2022-08-17
# 1  2022       3     8         17         3  2022-08-17
# 2  2022       3     8         17         3  2022-08-17
# 3  2022       3     8         17         3  2022-08-17
# 4  2022       3     8         17         3  2022-08-17
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        WN                                      WN
# 1                        WN                                      WN
# 2                        WN                                      WN
# 3                        WN                                      WN
# 4                        WN                                      WN
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19393                          WN  ...         NaN
# 1                    19393                          WN  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df8=df8[l]
df8
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            3     8         17         3  2022-08-17
# 1            3     8         17         3  2022-08-17
# 2            3     8         17         3  2022-08-17
# 3            3     8         17         3  2022-08-17
# 4            3     8         17         3  2022-08-17
# ...        ...   ...        ...       ...         ...
# 613644       3     8         10         3  2022-08-10
# 613645       3     8         16         2  2022-08-16
# 613646       3     8         17         3  2022-08-17
# 613647       3     8         18         4  2022-08-18
# 613648       3     8         19         5  2022-08-19
#
#        Marketing_Airline_Network    OriginCityName      DestCityName DepDelay  \
# 0                             WN       Chicago, IL   San Antonio, TX    -2.00
# 1                             WN       Chicago, IL      Savannah, GA    29.00
# 2                             WN       Chicago, IL    Louisville, KY    11.00
# ...

# %%
df8.shape
# Out:
# (613649, 19)

# %%
df9=pd.read_csv("Flights_2022_9.csv",sep=',', index_col=False, dtype='unicode')
df9.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       3     9          2         5  2022-09-02
# 1  2022       3     9          3         6  2022-09-03
# 2  2022       3     9          4         7  2022-09-04
# 3  2022       3     9          5         1  2022-09-05
# 4  2022       3     9          6         2  2022-09-06
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                            AA_CODESHARE
# 1                        AA                            AA_CODESHARE
# 2                        AA                            AA_CODESHARE
# 3                        AA                            AA_CODESHARE
# 4                        AA                            AA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19805                          AA  ...         NaN
# 1                    19805                          AA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df9=df9[l]
df9
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            3     9          2         5  2022-09-02
# 1            3     9          3         6  2022-09-03
# 2            3     9          4         7  2022-09-04
# 3            3     9          5         1  2022-09-05
# 4            3     9          6         2  2022-09-06
# ...        ...   ...        ...       ...         ...
# 580386       3     9         25         7  2022-09-25
# 580387       3     9         25         7  2022-09-25
# 580388       3     9         25         7  2022-09-25
# 580389       3     9         25         7  2022-09-25
# 580390       3     9         25         7  2022-09-25
#
#        Marketing_Airline_Network  OriginCityName  DestCityName DepDelay  \
# 0                             AA  Washington, DC     Greer, SC    -4.00
# 1                             AA  Washington, DC     Greer, SC    -6.00
# 2                             AA  Washington, DC     Greer, SC    -4.00
# ...

# %%
df9.shape
# Out:
# (580391, 19)

# %%
df10=pd.read_csv("Flights_2022_10.csv",sep=',', index_col=False, dtype='unicode')
df10.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       4    10         29         6  2022-10-29
# 1  2022       4    10         29         6  2022-10-29
# 2  2022       4    10         29         6  2022-10-29
# 3  2022       4    10         29         6  2022-10-29
# 4  2022       4    10         29         6  2022-10-29
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                                      UA
# 1                        UA                                      UA
# 2                        UA                                      UA
# 3                        UA                                      UA
# 4                        UA                                      UA
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19977                          UA  ...         NaN
# 1                    19977                          UA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df10=df10[l]
df10
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            4    10         29         6  2022-10-29
# 1            4    10         29         6  2022-10-29
# 2            4    10         29         6  2022-10-29
# 3            4    10         29         6  2022-10-29
# 4            4    10         29         6  2022-10-29
# ...        ...   ...        ...       ...         ...
# 595317       4    10         31         1  2022-10-31
# 595318       4    10         31         1  2022-10-31
# 595319       4    10         31         1  2022-10-31
# 595320       4    10         31         1  2022-10-31
# 595321       4    10         31         1  2022-10-31
#
#        Marketing_Airline_Network    OriginCityName       DestCityName  \
# 0                             UA      Columbus, OH        Houston, TX
# 1                             UA          Kona, HI    Los Angeles, CA
# 2                             UA       Seattle, WA         Newark, NJ
# ...

# %%
df10.shape
# Out:
# (595322, 19)

# %%
df11=pd.read_csv("Flights_2022_11.csv",sep=',', index_col=False, dtype='unicode')
df11.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       4    11         23         3  2022-11-23
# 1  2022       4    11         27         7  2022-11-27
# 2  2022       4    11         28         1  2022-11-28
# 3  2022       4    11         29         2  2022-11-29
# 4  2022       4    11         30         3  2022-11-30
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                            AA_CODESHARE
# 1                        AA                            AA_CODESHARE
# 2                        AA                            AA_CODESHARE
# 3                        AA                            AA_CODESHARE
# 4                        AA                            AA_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19805                          AA  ...         NaN
# 1                    19805                          AA  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df11=df11[l]
df11
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            4    11         23         3  2022-11-23
# 1            4    11         27         7  2022-11-27
# 2            4    11         28         1  2022-11-28
# 3            4    11         29         2  2022-11-29
# 4            4    11         30         3  2022-11-30
# ...        ...   ...        ...       ...         ...
# 567502       4    11         30         3  2022-11-30
# 567503       4    11          1         2  2022-11-01
# 567504       4    11          2         3  2022-11-02
# 567505       4    11          3         4  2022-11-03
# 567506       4    11          4         5  2022-11-04
#
#        Marketing_Airline_Network      OriginCityName  DestCityName DepDelay  \
# 0                             AA      Washington, DC  Hartford, CT    29.00
# 1                             AA      Washington, DC  Hartford, CT    52.00
# 2                             AA      Washington, DC  Hartford, CT    55.00
# ...

# %%
df11.shape
# Out:
# (567507, 19)

# %%
df12=pd.read_csv("Flights_2022_12.csv",sep=',', index_col=False, dtype='unicode')
df12.head()
# Out:
#    Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0  2022       4    12         19         1  2022-12-19
# 1  2022       4    12         20         2  2022-12-20
# 2  2022       4    12         21         3  2022-12-21
# 3  2022       4    12         22         4  2022-12-22
# 4  2022       4    12         23         5  2022-12-23
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                            DL_CODESHARE
# 1                        DL                            DL_CODESHARE
# 2                        DL                            DL_CODESHARE
# 3                        DL                            DL_CODESHARE
# 4                        DL                            DL_CODESHARE
#
#   DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ... Div5Airport  \
# 0                    19790                          DL  ...         NaN
# 1                    19790                          DL  ...         NaN
# ...

# %%
l = ["Quarter", "Month","DayofMonth", "DayOfWeek", "FlightDate", "Marketing_Airline_Network", "OriginCityName", "DestCityName", "DepDelay", "ArrDelay", "Cancelled", "Diverted", "AirTime", "Distance", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"]
df12=df12[l]
df12
# Out:
#        Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0            4    12         19         1  2022-12-19
# 1            4    12         20         2  2022-12-20
# 2            4    12         21         3  2022-12-21
# 3            4    12         22         4  2022-12-22
# 4            4    12         23         5  2022-12-23
# ...        ...   ...        ...       ...         ...
# 578316       4    12         27         2  2022-12-27
# 578317       4    12         28         3  2022-12-28
# 578318       4    12         29         4  2022-12-29
# 578319       4    12         30         5  2022-12-30
# 578320       4    12         31         6  2022-12-31
#
#        Marketing_Airline_Network   OriginCityName     DestCityName DepDelay  \
# 0                             DL     Hartford, CT     New York, NY    -5.00
# 1                             DL     Hartford, CT     New York, NY    -5.00
# 2                             DL     Hartford, CT     New York, NY    -2.00
# ...

# %%
df12.shape
# Out:
# (578321, 19)

# %%
df1_2=pd.concat([df1,df2],ignore_index=True)
df1_2
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             1     1          6         4  2022-01-06
# 1             1     1          6         4  2022-01-06
# 2             1     1          6         4  2022-01-06
# 3             1     1          6         4  2022-01-06
# 4             1     1          6         4  2022-01-06
# ...         ...   ...        ...       ...         ...
# 1083684       1     2         25         5  2022-02-25
# 1083685       1     2         23         3  2022-02-23
# 1083686       1     2         22         2  2022-02-22
# 1083687       1     2         16         3  2022-02-16
# 1083688       1     2         15         2  2022-02-15
#
#         Marketing_Airline_Network       OriginCityName           DestCityName  \
# 0                              DL  Fort Lauderdale, FL           New York, NY
# 1                              DL          Atlanta, GA    Fort Lauderdale, FL
# ...

# %%
df3_4=pd.concat([df3,df4],ignore_index=True)
df3_4
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             1     3          8         2  2022-03-08
# 1             1     3         12         6  2022-03-12
# 2             1     3         15         2  2022-03-15
# 3             1     3         19         6  2022-03-19
# 4             1     3         22         2  2022-03-22
# ...         ...   ...        ...       ...         ...
# 1170827       2     4          4         1  2022-04-04
# 1170828       2     4          4         1  2022-04-04
# 1170829       2     4          4         1  2022-04-04
# 1170830       2     4          4         1  2022-04-04
# 1170831       2     4          4         1  2022-04-04
#
#         Marketing_Airline_Network      OriginCityName         DestCityName  \
# 0                              DL       Knoxville, TN          Atlanta, GA
# 1                              DL     Minneapolis, MN  Fort Lauderdale, FL
# 2                              DL       Knoxville, TN          Atlanta, GA
# ...

# %%
df5_6=pd.concat([df5,df6],ignore_index=True)
df5_6
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             2     5          3         2  2022-05-03
# 1             2     5          4         3  2022-05-04
# 2             2     5          1         7  2022-05-01
# 3             2     5          2         1  2022-05-02
# 4             2     5          3         2  2022-05-03
# ...         ...   ...        ...       ...         ...
# 1205002       2     6         21         2  2022-06-21
# 1205003       2     6         21         2  2022-06-21
# 1205004       2     6         22         3  2022-06-22
# 1205005       2     6         22         3  2022-06-22
# 1205006       2     6         23         4  2022-06-23
#
#         Marketing_Airline_Network      OriginCityName        DestCityName  \
# 0                              AA      Washington, DC          Albany, NY
# 1                              AA      Washington, DC          Albany, NY
# 2                              AA       Charlotte, NC     Tallahassee, FL
# ...

# %%
df7_8=pd.concat([df7,df8],ignore_index=True)
df7_8
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             3     7         19         2  2022-07-19
# 1             3     7         20         3  2022-07-20
# 2             3     7         21         4  2022-07-21
# 3             3     7         24         7  2022-07-24
# 4             3     7         25         1  2022-07-25
# ...         ...   ...        ...       ...         ...
# 1232434       3     8         10         3  2022-08-10
# 1232435       3     8         16         2  2022-08-16
# 1232436       3     8         17         3  2022-08-17
# 1232437       3     8         18         4  2022-08-18
# 1232438       3     8         19         5  2022-08-19
#
#         Marketing_Airline_Network    OriginCityName      DestCityName  \
# 0                              AA    Washington, DC         Tulsa, OK
# 1                              AA    Washington, DC         Tulsa, OK
# 2                              AA    Washington, DC         Tulsa, OK
# ...

# %%
df9_10=pd.concat([df9,df10],ignore_index=True)
df9_10
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             3     9          2         5  2022-09-02
# 1             3     9          3         6  2022-09-03
# 2             3     9          4         7  2022-09-04
# 3             3     9          5         1  2022-09-05
# 4             3     9          6         2  2022-09-06
# ...         ...   ...        ...       ...         ...
# 1175708       4    10         31         1  2022-10-31
# 1175709       4    10         31         1  2022-10-31
# 1175710       4    10         31         1  2022-10-31
# 1175711       4    10         31         1  2022-10-31
# 1175712       4    10         31         1  2022-10-31
#
#         Marketing_Airline_Network    OriginCityName      DestCityName  \
# 0                              AA    Washington, DC         Greer, SC
# 1                              AA    Washington, DC         Greer, SC
# 2                              AA    Washington, DC         Greer, SC
# ...

# %%
df11_12=pd.concat([df11,df12],ignore_index=True)
df11_12
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             4    11         23         3  2022-11-23
# 1             4    11         27         7  2022-11-27
# 2             4    11         28         1  2022-11-28
# 3             4    11         29         2  2022-11-29
# 4             4    11         30         3  2022-11-30
# ...         ...   ...        ...       ...         ...
# 1145823       4    12         27         2  2022-12-27
# 1145824       4    12         28         3  2022-12-28
# 1145825       4    12         29         4  2022-12-29
# 1145826       4    12         30         5  2022-12-30
# 1145827       4    12         31         6  2022-12-31
#
#         Marketing_Airline_Network   OriginCityName     DestCityName DepDelay  \
# 0                              AA   Washington, DC     Hartford, CT    29.00
# 1                              AA   Washington, DC     Hartford, CT    52.00
# ...

# %%
df1234=pd.concat([df1_2,df3_4],ignore_index=True)
df1234
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             1     1          6         4  2022-01-06
# 1             1     1          6         4  2022-01-06
# 2             1     1          6         4  2022-01-06
# 3             1     1          6         4  2022-01-06
# 4             1     1          6         4  2022-01-06
# ...         ...   ...        ...       ...         ...
# 2254516       2     4          4         1  2022-04-04
# 2254517       2     4          4         1  2022-04-04
# 2254518       2     4          4         1  2022-04-04
# 2254519       2     4          4         1  2022-04-04
# 2254520       2     4          4         1  2022-04-04
#
#         Marketing_Airline_Network       OriginCityName           DestCityName  \
# 0                              DL  Fort Lauderdale, FL           New York, NY
# 1                              DL          Atlanta, GA    Fort Lauderdale, FL
# ...

# %%
df5678=pd.concat([df5_6,df7_8],ignore_index=True)
df5678
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             2     5          3         2  2022-05-03
# 1             2     5          4         3  2022-05-04
# 2             2     5          1         7  2022-05-01
# 3             2     5          2         1  2022-05-02
# 4             2     5          3         2  2022-05-03
# ...         ...   ...        ...       ...         ...
# 2437441       3     8         10         3  2022-08-10
# 2437442       3     8         16         2  2022-08-16
# 2437443       3     8         17         3  2022-08-17
# 2437444       3     8         18         4  2022-08-18
# 2437445       3     8         19         5  2022-08-19
#
#         Marketing_Airline_Network    OriginCityName      DestCityName  \
# 0                              AA    Washington, DC        Albany, NY
# 1                              AA    Washington, DC        Albany, NY
# 2                              AA     Charlotte, NC   Tallahassee, FL
# ...

# %%
df9101112=pd.concat([df9_10,df11_12],ignore_index=True)
df9101112
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             3     9          2         5  2022-09-02
# 1             3     9          3         6  2022-09-03
# 2             3     9          4         7  2022-09-04
# 3             3     9          5         1  2022-09-05
# 4             3     9          6         2  2022-09-06
# ...         ...   ...        ...       ...         ...
# 2321536       4    12         27         2  2022-12-27
# 2321537       4    12         28         3  2022-12-28
# 2321538       4    12         29         4  2022-12-29
# 2321539       4    12         30         5  2022-12-30
# 2321540       4    12         31         6  2022-12-31
#
#         Marketing_Airline_Network   OriginCityName     DestCityName DepDelay  \
# 0                              AA   Washington, DC        Greer, SC    -4.00
# 1                              AA   Washington, DC        Greer, SC    -6.00
# ...

# %%
df1to8=pd.concat([df1234,df5678],ignore_index=True)
df1to8
# Out:
#         Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0             1     1          6         4  2022-01-06
# 1             1     1          6         4  2022-01-06
# 2             1     1          6         4  2022-01-06
# 3             1     1          6         4  2022-01-06
# 4             1     1          6         4  2022-01-06
# ...         ...   ...        ...       ...         ...
# 4691962       3     8         10         3  2022-08-10
# 4691963       3     8         16         2  2022-08-16
# 4691964       3     8         17         3  2022-08-17
# 4691965       3     8         18         4  2022-08-18
# 4691966       3     8         19         5  2022-08-19
#
#         Marketing_Airline_Network       OriginCityName           DestCityName  \
# 0                              DL  Fort Lauderdale, FL           New York, NY
# 1                              DL          Atlanta, GA    Fort Lauderdale, FL
# ...

# %%
df=pd.concat([df1to8,df9101112],ignore_index=True)
df.head()
# Out:
#   Quarter Month DayofMonth DayOfWeek  FlightDate Marketing_Airline_Network  \
# 0       1     1          6         4  2022-01-06                        DL
# 1       1     1          6         4  2022-01-06                        DL
# 2       1     1          6         4  2022-01-06                        DL
# 3       1     1          6         4  2022-01-06                        DL
# 4       1     1          6         4  2022-01-06                        DL
#
#         OriginCityName           DestCityName DepDelay ArrDelay Cancelled  \
# 0  Fort Lauderdale, FL           New York, NY      NaN      NaN      1.00
# 1          Atlanta, GA    Fort Lauderdale, FL    -4.00    -1.00      0.00
# 2  Fort Lauderdale, FL            Atlanta, GA    -2.00   -12.00      0.00
# 3  Fort Lauderdale, FL     Raleigh/Durham, NC    -5.00   -15.00      0.00
# 4          Atlanta, GA  Jackson/Vicksburg, MS    -4.00   -11.00      0.00
#
# ...

# %%
df.shape
# Out:
# (7013508, 19)

# %%
df.to_csv('2022_Flights.csv')
